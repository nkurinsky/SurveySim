# %%
# %matplotlib inline
import pyfits
import numpy
from pylab import *

# %%
hdus=pyfits.open("output.fits")

# %%
hdus.info()
# Out:
# Filename: output.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      24   (57, 57)     float64
# 1    model       ImageHDU         9   (57, 57)     int32
# 2    observation  ImageHDU         9   (57, 57)     int32
# 3    Parameter Distributions  TableHDU        65   3745R x 14C   [F13.8, F13.8, F13.8, F13.8, E13.5, F13.8, F13.8, F13.8, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5]
# 4    Chain       TableHDU        89   140R x 20C   [E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5, E13.5]
# 5    Convergence  TableHDU        17   500R x 2C    [F5.2, F5.2]
# 6    Results     BinTableHDU     17   700R x 4C    [1D, 27D, 36D, 35D]
# 7    Counts Monte Carlo  BinTableHDU     17   999R x 4C    [1D, 27D, 36D, 35D]

# %%
hdus[2].header
# Out:
# XTENSION= 'IMAGE   '           / IMAGE extension
# BITPIX  =                   32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                   57 / length of data axis 1
# NAXIS2  =                   57 / length of data axis 2
# PCOUNT  =                    0 / required keyword; must = 0
# GCOUNT  =                    1 / required keyword; must = 1
# EXTNAME = 'observation'
# HDUVERS =                    1

# %%
def imgcontour (data,levels,extent):
    cset = contour(data, levels, origin="lower",colors="black",extent=extent)
    clabel(cset, inline=1, fontsize=10, fmt="%2.0i")
    for c in cset.collections:
        c.set_linestyle("solid")

# %%
extent = [hdus[0].header['H_MIN_Y'], hdus[0].header['H_MAX_Y'], hdus[0].header['H_MIN_X'], hdus[0].header['H_MAX_X']]
print(hdus[1].data.max())
levels=(30,20,10,2)
reslevels=(10,1)

figure(1,figsize=(12,4))
for i in range(0,3):
    subplot(1,3,i+1)
    print(hdus[i].data.sum())
    if(i==0):
        title('Residual')
        ylabel('Axis 2')
        imgcontour(hdus[i].data,reslevels,extent)
    else:
        if(i==1):
            title('Model')
        else:
            title('Observation')
        imgcontour(hdus[i].data,levels,extent)
    xlabel('Axis 1')
    xlim(0.5,2.5)
    ylim(-0.75,0.75)
show()
# Out:
# 44
# 663.95521225
# 3725
# 4228

# %%
dists=hdus[3].data
#hdus[3].data.names
chainchi=hdus[7].data['chisq']
chimed=median(chainchi)
gpts=numpy.where(chainchi < chimed)

s1=dists['s1']
od1=dists['obs_dnds1']
md1=dists['mod_dnds1']

d1chain=hdus[7].data['dnds1'][gpts]
mins1=numpy.zeros(len(s1))
maxs1=numpy.zeros(len(s1))
for i in range(0,len(d1chain[0])):
    mins1[i]=min(d1chain[:,i])
    maxs1[i]=max(d1chain[:,i])

pts1=where(md1 > 1.0)
plot(s1[pts1],od1[pts1],'o',label="Observation")
plot(s1[pts1],md1[pts1],'o',label="Model")
errorbar(s1[pts1],md1[pts1],yerr=[mins1[pts1],maxs1[pts1]],linestyle="None")
title("Counts Band 1")
xlabel('Flux [mJy]')
ylabel('DnDs*Jy^(-1.5)')
xscale('log')
yscale('log')
legend(loc='lower right')
ylim(1e0,1e5)
show()

s2=dists['s2']
od2=dists['obs_dnds2']
md2=dists['mod_dnds2']

d2chain=hdus[7].data['dnds2'][gpts]
std2=numpy.zeros(len(s2))
for i in range(0,len(d2chain[0])):
    std2[i]=std(d2chain[:,i])

pts2=where(md2 > 1.0)
plot(s2[pts2],od2[pts2],'o',label="Observation")
plot(s2[pts2],md2[pts2],'o',label="Model")
errorbar(s2[pts2],md2[pts2],yerr=std2[pts2],linestyle="None")
title("Counts Band 2")
xlabel('Flux [mJy]')
ylabel('DnDs*Jy^(-1.5)')
xscale('log')
yscale('log')
legend(loc='lower right')
ylim(1e0,1e5)
show()

s3=dists['s3']
od3=dists['obs_dnds3']
md3=dists['mod_dnds3']

d3chain=hdus[7].data['dnds3'][gpts]
std3=numpy.zeros(len(s3))
for i in range(0,len(d3chain[0])):
    std3[i]=std(d3chain[:,i])

pts3=where(md3 > 1.0)
plot(s3[pts3],od3[pts3],'o',label="Observation")
plot(s3[pts3],md3[pts3],'o',label="Model")
errorbar(s3[pts3],md3[pts3],yerr=std3[pts3],linestyle="None")
title("Counts Band 3")
xlabel('Flux [mJy]')
ylabel('DnDs*Jy^(-1.5)')
xscale('log')
yscale('log')
legend(loc='lower right')
ylim(1e0,1e5)
show()

# %%
dists.columns
# Out:
# ColDefs(
#     name = 'F1'; format = 'F13.8'; unit = 'Jy'; start = 1
#     name = 'F2'; format = 'F13.8'; unit = 'Jy'; start = 15
#     name = 'F3'; format = 'F13.8'; unit = 'Jy'; start = 29
#     name = 'Z'; format = 'F13.8'; unit = '-'; start = 43
#     name = 'Lum'; format = 'E13.5'; unit = 'W/Hz'; start = 57
#     name = 's1'; format = 'F13.8'; unit = 'mJy'; start = 71
#     name = 's2'; format = 'F13.8'; unit = 'mJy'; start = 85
#     name = 's3'; format = 'F13.8'; unit = 'mJy'; start = 99
#     name = 'obs_dnds1'; format = 'E13.5'; unit = 'Jy^1.5/sr'; start = 113
#     name = 'obs_dnds2'; format = 'E13.5'; unit = 'Jy^1.5/sr'; start = 127
#     name = 'obs_dnds3'; format = 'E13.5'; unit = 'Jy^1.5/sr'; start = 141
#     name = 'mod_dnds1'; format = 'E13.5'; unit = 'Jy^1.5/sr'; start = 155
#     name = 'mod_dnds2'; format = 'E13.5'; unit = 'Jy^1.5/sr'; start = 169
#     name = 'mod_dnds3'; format = 'E13.5'; unit = 'Jy^1.5/sr'; start = 183
# )

# %%
def bins (dat): return int(ceil(pow(len(dat),0.333)))
def binSize (dat): return 2.4*std(dat)/pow(len(dat),0.333)
def nbins (dat): return int(ceil((max(dat)-min(dat))/binSize(dat)))
def nbins2 (dat): return int(ceil((max(dat)-min(dat))/binSize(dat)/2))

# %%
print(len((dists['Lum'])))
print(nbins(dists['z']))
print(binSize(dists['z']))
# Out:
# 3745
# 29
# 0.175791244547

# %%
hist(dists['Lum'],bins=nbins(dists['Lum']),histtype='step',color="black");
xlabel('Lum')
ylabel('N(Lum)')
show()
hist(dists['z'],bins=nbins(dists['z']),histtype='step',color="black");
xlabel('z')
ylabel('N(z)')
show()

# %%
def contour2d (x,y):
    H, xedges, yedges = histogram2d(y, x, bins=(nbins2(y), nbins2(x)),normed=True)
    extent = [yedges[0], yedges[-1], xedges[0], xedges[-1]]
    levels = (0.5,0.4,0.3,0.2,0.15,0.1,0.075,0.06,0.05,0.035,0.02)
    cset = contour(H, levels, origin="lower",linewidths=(1.9, 1.6, 1.5, 1.4),colors="black",extent=extent)
    clabel(cset, inline=1, fontsize=10, fmt="%0.2f")
    for c in cset.collections:
        c.set_linestyle("solid")

# %%
params=hdus[4].data
cols=params.names
chain_num=0
param_num=0
pnames=[]
for col in cols:
    if "0" in col:
        if not (("CHISQ" in col) | ("ACPT" in col)):
            ptemp=col.split('0')[0]
            pnames.append(ptemp)
    if "CHISQ" in col:
        chain_num+=1

pchains=[]
for i in range(0,len(pnames)):
    p=pnames[i]
    pdat=[]
    for i in range(0,chain_num):
        pdat.extend(params[p+str(i)])
    pchains.append(pdat)
    
figure(figsize=(8,8))
for i in range(0,len(pnames)):
    for j in range(0,len(pnames)):
        if(i >= j):
            subplot(len(pnames),len(pnames),i*len(pnames)+j+1)
        if(i == j):
            hist(pchains[i],bins=nbins(pchains[i]),normed=True,histtype='step',color="black")
            if(j == 0):
                ylabel("Relative Probability")
        elif(i > j):
            contour2d(pchains[j],pchains[i])
            if(j == 0):
                ylabel(pnames[i])
        if(i == (len(pnames)-1)):
            xlabel(pnames[j])
show()
